# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))
x = np.linspace(-6, 6, 1001)
ind = np.where(x == 0.)
x = np.delete(x, ind)
y1 = x**2 - 1
y2 = (np.exp(x) - 1) / x + 1
plt.plot(x, y1, label = 'x^2 - 1', c = 'g')
plt.plot(x, y2, label = '(e^x - 1)/x + 1', c = 'b')
plt.axis([-6, 6, -3, 30])
plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
from scipy.optimize import fsolve
from scipy import optimize

def equations(p):
    x, y = p
    return(y - x**2 + 1, np.exp(x) + x * (1 - y) - 1)
x_1, y_1 = fsolve(equations, (-2, 5))
x_2, y_2 = fsolve(equations, (3, 6))
x_3, y_3 = fsolve(equations, (5, 20))

print(x_1, y_1)
print(x_2, y_2)
print(x_3, y_3)
# Out:
# -1.5818353528958997 1.5022030836712943
# 2.618145573086073 5.8546862418707315
# 4.200105840743156 16.640889073515883
